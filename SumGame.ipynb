# %%
# Sum Game

print("Welcome to Sum Game", "\n")

print("Sum Game Description:")
print("This game was founded by Ashik", "\n")

print("At the start of the game two cards will be dealt for you")
print("Then the sum of the two cards will be shown to you", "\n")

print("Based on the sum of the first two cards you have to guess how the sum of next two cards will be")
print("You will be asked to choose from the following 3 options:" + "\n" + "Less" + "\n" + "More" + "\n" + "Equal" + "\n")
print("The options are case sensitive and you have to choose one and type it in the input box")
print("If the options are entered incorrectly, you will be asked to re-enter a valid option", "\n")

print("Next you have to enter the amount you would like to bet in the input box")
print("Similarly if the bet amount is entered incorrectly, you will be asked to re-enter a valid amount", "\n")

print("If you choose Less or more as your choice option and it turns out to be right, then you win the bet amount")
print("If you choose Less or more as your choice option and it turns out to be wrong, then you lose the bet amount", "\n")

print("If you choose Equal as your choice option and it turns out to be right, then you win double the bet amount")
print("If you choose Equal as your choice option and it turns out to be wrong, then you lose double the bet amount", "\n")

print("Next the third and fourth cards are dealt and their sum is displayed")
print("Along with that your result is displayed if you have won or lost", "\n")

print("Finally your current account balance amount after the round of game is shown to you")
print("If you finish your bet amount and it goes to 0 then the game terminates automatically")
print("After every 5 rounds you will be asked if you want to continue playing. Choose 'N' or 'n' to quit")
print("If you decide to quit playing in the middle then Choose 'Q' or 'q' in the choice input to quit", "\n")

import random

# Writing a function called chosen to determine if the second number is more or less or equal to the first number

def chosen(num1, num2):
    
    if num2 > num1:
        return "More"
    elif num2 < num1:
        return "Less"
    else:
        return "Equal"
    
money = 50
current_round = 1

print("Your account balance at start: $", money, "\n")

while True:
    card1 = random.randint(1,13)
    card2 = random.randint(1,13)
    
    sum12 = card1 + card2
    
    print("Round", current_round, "\n")
    
    print("SUM GAME BEGINS NOW!!", "\n")
    
    print("Your first two cards are: ", card1,"\t", card2)
    print("The sum of your first two cards are: ", sum12, "\n")
        
    print("Sum of your next two numbers will be? " + "\n" + "Less" + "\n" + "More" + "\n" + "Equal" + "\n")
    
    choice = input("Enter your Choice? ")
    
    if choice == "Q" or choice == "q":
        break
        
    while True: 
        if choice == 'Less' or choice == 'More' or choice == 'Equal': 
            break
        else:
            print("Please choose and enter a valid option", "\n")
            choice = input("Enter your Choice? ")  
    
    bet = int(input("How much do you want to bet? "))  
    while bet > money or bet < 0:
        print("Please enter a valid amount")
        bet = int(input("How much do you want to bet? ")) 
    
    card3 = random.randint(1,13)
    card4 = random.randint(1,13)
    
    sum34 = card3 + card4
    
    print("\n" + "Your next two cards are: ", card3,"\t", card4)
    print("The sum of your next two cards are: ", sum34, "\n")
    
    if bet != 0:
        if choice == chosen(sum12, sum34):
            if chosen(sum12, sum34) == 'Equal':
                print('Yay!! You Won Double bonus!! Congrats!!')
                money += (bet * 2)
            else:
                print('Yay!! Congrats!! You Won!!')
                money += bet
        elif choice == 'Equal' and chosen(sum12, sum34) != 'Equal':
            print('Sorry, You Lost Double bonus!! Better luck next time!!')
            money -= (bet * 2)
        else:
            print('Sorry, You Lost. Better luck next time!!')
            money -= bet
        
    # if you are out of money, leave the loop
    print("Now your account balance is: $", money, "\n")
    print("-" * 117, "\n")
    if money <= 0:
        break
        
    if current_round % 5 == 0:
        cont_play = input("Do you want to continue playing Y/N: ")
        if cont_play == "N" or cont_play == "n":
            break # stops the loop from running and exits the loop
    
    current_round += 1

print("\n" + "Thanks for playing Sum Game. Have a great day. Good bye!!")
# Out:
# Welcome to Sum Game
#
# Sum Game Description:
# This game was founded by Ashik
#
# At the start of the game two cards will be dealt for you
# Then the sum of the two cards will be shown to you
#
# Based on the sum of the first two cards you have to guess how the sum of next two cards will be
# You will be asked to choose from the following 3 options:
# Less
# More
# Equal
#
# The options are case sensitive and you have to choose one and type it in the input box
# If the options are entered incorrectly, you will be asked to re-enter a valid option
#
# Next you have to enter the amount you would like to bet in the input box
# Similarly if the bet amount is entered incorrectly, you will be asked to re-enter a valid amount
#
# If you choose Less or more as your choice option and it turns out to be right, then you win the bet amount
# If you choose Less or more as your choice option and it turns out to be wrong, then you lose the bet amount
#
# If you choose Equal as your choice option and it turns out to be right, then you win double the bet amount
# If you choose Equal as your choice option and it turns out to be wrong, then you lose double the bet amount
#
# Next the third and fourth cards are dealt and their sum is displayed
# Along with that your result is displayed if you have won or lost
#
# Finally your current account balance amount after the round of game is shown to you
# If you finish your bet amount and it goes to 0 then the game terminates automatically
# After every 5 rounds you will be asked if you want to continue playing. Choose 'N' or 'n' to quit
# If you decide to quit playing in the middle then Choose 'Q' or 'q' in the choice input to quit
#
# Your account balance at start: $ 50
#
# Round 1
#
# SUM GAME BEGINS NOW!!
#
# Your first two cards are:  1 	 12
# The sum of your first two cards are:  13
#
# Sum of your next two numbers will be?
# Less
# More
# Equal
#
# Enter your Choice? Equal
# How much do you want to bet? 20
#
# Your next two cards are:  1 	 3
# The sum of your next two cards are:  4
#
# Sorry, You Lost Double bonus!! Better luck next time!!
# Now your account balance is: $ 10
#
# ---------------------------------------------------------------------------------------------------------------------
#
# Round 2
#
# SUM GAME BEGINS NOW!!
#
# Your first two cards are:  3 	 10
# The sum of your first two cards are:  13
#
# Sum of your next two numbers will be?
# Less
# More
# Equal
#
# Enter your Choice? Q
#
# Thanks for playing Sum Game. Have a great day. Good bye!!

# %%
# Sim/Dif Game

import random

# Writing a function called similar to determine if the second two numbers are similar or different to the first two numbers

def similar(num1, num2, num3, num4):
    
    if (num1 == num3 and num2 == num4) or (num1 == num4 and num2 == num3):
        return "2"
    elif (num1 == num3 and num2 != num4) or (num1 != num3 and num2 == num4) or (num1 == num4 and num2 != num3) or (num1 != num4 and num2 == num3):
        return "1"
    else:
        return "0"
    
money = 50
current_round = 1

print("Your account balance at start: $", money, "\n")

while True:
    card1 = random.randint(1,13)
    card2 = random.randint(1,13)
    
    print("Round", current_round, "\n")
    
    print("GAME BEGINS NOW!!", "\n")
    
    print("Your first two cards are: ", card1,"\t", card2, "\n")
        
    print("How many numbers will be similar? " + "\n" + "0" + "\n" + "1" + "\n" + "2" + "\n")
    
    choice = input("Enter your Choice? ")
    
    if choice == "Q" or choice == "q":
        break
    
    while True: 
        if choice == "0" or choice == "1" or choice == "2": 
            break
        else:
            print("Please choose and enter a valid option", "\n")
            choice = input("Enter your Choice? ")  
    
    bet = int(input("How much do you want to bet? "))  
    while bet > money or bet < 0:
        print("Please enter a valid amount")
        bet = int(input("How much do you want to bet? ")) 
    
    card3 = random.randint(1,13)
    card4 = random.randint(1,13)
    
    print("\n" + "Your next two cards are: ", card3,"\t", card4, "\n")
    
    if bet != 0:
        if choice == similar(card1, card2, card3, card4):
            if choice == '2':
                print('Yay!! Both cards are Same!! You got Triple bonus!! Congrats!!')
                money += (bet * 3)    
            elif choice == '1':
                print('Yay!! One card is Same!! You got Double bonus!! Congrats!!')
                money += (bet * 2)
            else:
                print('Yay!! Both are different!! Congrats!! You Won!!')
                money += bet             
        else:
            if choice == '2':
                print('Sorry, You Lost Triple bonus!! Better luck next time!!')
                money -= (bet * 3)   
            elif choice ==  '1':
                print('Sorry, You Lost Double bonus!! Better luck next time!!')
                money -= (bet * 2)
            else:
                print('Sorry, You Lost. Better luck next time!!')
                money -= bet 

        
    # if you are out of money, leave the loop
    print("Now your account balance is: $", money, "\n")
    print("-" * 117, "\n")
    if money <= 0:
        break
        
    if current_round % 5 == 0:
        cont_play = input("Do you want to continue playing Y/N: ")
        if cont_play == "N" or cont_play == "n":
            break # stops the loop from running and exits the loop
    
    current_round += 1

print("\n" + "Thanks for playing. Have a great day. Good bye!!")
# Out:
# Your account balance at start: $ 50
#
# Round 1
#
# GAME BEGINS NOW!!
#
# Your first two cards are:  5 	 1
#
# How many numbers will be similar?
# 0
# 1
# 2
#
# Enter your Choice? 10
# Please choose and enter a valid option
#
# Enter your Choice? 1
# How much do you want to bet? 10
#
# Your next two cards are:  10 	 11
#
# Sorry, You Lost Double bonus!! Better luck next time!!
# Now your account balance is: $ 30
#
# ---------------------------------------------------------------------------------------------------------------------
#
# Round 2
#
# GAME BEGINS NOW!!
#
# Your first two cards are:  6 	 9
#
# How many numbers will be similar?
# 0
# 1
# 2
